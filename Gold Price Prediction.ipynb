# %%
# importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the csv data to a Pandas DataFrame
df = pd.read_csv('gold_price_data.csv')

# %%
df.head()
# Out:
#        Date          SPX       Glod        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
# number of rows and columns
df.shape
# Out:
# (2290, 6)

# %%
# getting some basic informations about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   Glod     2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
# checking the number of missing values
df.isnull().sum()
# Out:
# Date       0
# SPX        0
# Glod       0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
# getting the statistical measures of the data
df.describe(percentiles=[0.1,0.25,0.5,0.75,0.9])
# Out:
#                SPX         Glod          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 10%    1054.510974    91.083996    10.568000    13.620000     1.095542
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# 90%    2387.517944   160.463007    41.333002    31.590000     1.443872
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
df.columns
# Out:
# Index(['Date', 'SPX', 'Glod', 'USO', 'SLV', 'EUR/USD'], dtype='object')

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df
# Out:
#               SPX        Glod        USO      SLV   EUR/USD
# 0     1447.160034   84.860001  78.470001  15.1800  1.471692
# 1     1447.160034   85.570000  78.370003  15.2850  1.474491
# 2     1411.630005   85.129997  77.309998  15.1670  1.475492
# 3     1416.180054   84.769997  75.500000  15.0530  1.468299
# 4     1390.189941   86.779999  76.059998  15.5900  1.557099
# ...           ...         ...        ...      ...       ...
# 2285  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 5 columns]

# %%
# Basic plotting and visualization on the data set

# %%
# pairplots using seaborn

# %%
sns.pairplot(df)
plt.show()

# %%
# Distribution of EUR( the predicted quantity)

# %%
df['EUR/USD'].plot.hist(bins=25,figsize=(8,4))
plt.show()

# %%
df['EUR/USD'].plot.density()
plt.show()

# %%
# correlation matrix and heatmap

# %%
numeric_df = df.select_dtypes(include = ['float64','int64'])

# %%
numeric_df.corr()
# Out:
#               SPX      Glod       USO       SLV   EUR/USD
# SPX      1.000000  0.049345 -0.591573 -0.274055 -0.672017
# Glod     0.049345  1.000000 -0.186360  0.866632 -0.024375
# USO     -0.591573 -0.186360  1.000000  0.167547  0.829317
# SLV     -0.274055  0.866632  0.167547  1.000000  0.321631
# EUR/USD -0.672017 -0.024375  0.829317  0.321631  1.000000

# %%
sns.heatmap(numeric_df.corr(),annot= True,linewidths=1)
plt.show()

# %%
l_column = list(df.columns) # Making a list out of column names
len_feature = len(l_column) # Length of column vector list
print(len_feature)
l_column
# Out:
# 5
# ['SPX', 'Glod', 'USO', 'SLV', 'EUR/USD']

# %%
# Put all the numerical features in X and EUR/USD in y

# %%
X = df[l_column[0:len_feature-1]]
y = df[l_column[len_feature-1]]

# %%
# Normaliztion

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit_transform(X)
# Out:
# array([[0.35087007, 0.12967974, 0.64380934, 0.16480084],
#        [0.35087007, 0.13587574, 0.64289628, 0.1675345 ],
#        [0.33469315, 0.13203593, 0.63321764, 0.16446239],
#        ...,
#        [0.9317956 , 0.48154291, 0.05889335, 0.17938038],
#        [0.93500996, 0.47552142, 0.05861943, 0.1746941 ],
#        [0.93302946, 0.45853741, 0.058855  , 0.17193961]])

# %%
for i in range(len(l_column)-1):
    sns.boxplot(x='EUR/USD',y=l_column[i], data=df)
    plt.figure()
    plt.show()

# %%
print("Feature set size:",X.shape)
print("Variable set size:",y.shape)
# Out:
# Feature set size: (2290, 4)
# Variable set size: (2290,)

# %%
X.head()
# Out:
#            SPX       Glod        USO     SLV
# 0  1447.160034  84.860001  78.470001  15.180
# 1  1447.160034  85.570000  78.370003  15.285
# 2  1411.630005  85.129997  77.309998  15.167
# 3  1416.180054  84.769997  75.500000  15.053
# 4  1390.189941  86.779999  76.059998  15.590

# %%
# Test-train split
#import train_test_split function from scikit_learn

# %%
from sklearn.model_selection import train_test_split

# %%
# create X and y and test splits in one command using a split ratio and random seed

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size =0.3,random_state =123 )

# %%
# Check the size and shape of train/test splits (it should be in the ratio as per test_size parameter above)

# %%
print("Training feature set size:",X_train.shape)
print("Test feature set size:",X_test.shape)
print("Training variable set size:",y_train.shape)
print("Test variable set size:",y_test.shape)
# Out:
# Training feature set size: (1603, 4)
# Test feature set size: (687, 4)
# Training variable set size: (1603,)
# Test variable set size: (687,)

# %%
# import linear regression model

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics 
from sklearn.metrics import accuracy_score

# %%
lm = LinearRegression() # Creating a linear Regression model

# %%
# fit the model on to the instantiated object itself

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Check the intercept and coefficients and put them in a DataFrame

# %%
print("The intercept term of the linear model:", lm.intercept_)
# Out:
# The intercept term of the linear model: 1.2183745927434289

# %%
print("The coefficients of the linear model:", lm.coef_)
# Out:
# The coefficients of the linear model: [-5.39280161e-05 -6.17960974e-04  4.29894835e-03  4.66319526e-03]

# %%
train_pred=lm.predict(X_train)

# %%
# R-square of the model fit :number from 0 to 1

# %%
print("R-squared value of this fit:",round(metrics.r2_score(y_train,train_pred),3))
# Out:
# R-squared value of this fit: 0.756

# %%
# prediction using the ml model

# %%
predictions = lm.predict(X_test)
print ("Type of the predicted object:", type(predictions))
print ("Size of the predicted object:", predictions.shape)
# Out:
# Type of the predicted object: <class 'numpy.ndarray'>
# Size of the predicted object: (687,)

# %%
plt.figure(figsize=(10,7))
plt.title("Actual vs. predicted glod prices",fontsize=20)
plt.xlabel("Actual test set glod prices",fontsize=18)
plt.ylabel("Predicted house prices", fontsize=18)
plt.scatter(x=y_test,y=predictions)
plt.show()

# %%
# Regression evaluation metrices

# %%
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y_test,predictions))
print("Mean square error (MSE):", metrics.mean_squared_error(y_test,predictions))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# Mean absolute error (MAE): 0.05294027752869818
# Mean square error (MSE): 0.004004472486710202
# Root mean square error (RMSE): 0.0632809014372441

# %%
# R-square value

# %%
print("R-squared value of predictions:",round(metrics.r2_score(y_test,predictions),3))
# Out:
# R-squared value of predictions: 0.768

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %%
# model Training :Random Forest Regressor

# %%
regressor = RandomForestRegressor(n_estimators=100)

# %%
# training the model
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
# model Evaluation

# %%
# prediction on Test Data
test_data_prediction = regressor.predict(X_test)

# %% [raw]
# print(test_data_prediction)

# %%
# R squared error
error_score = metrics.r2_score(y_test,test_data_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.9811420885637235

# %%
# compare the actual values and predicted values in a plot

# %%
y_test = list(y_test)

# %%
plt.plot(y_test,color = 'blue', label= 'Actual Value')
plt.plot(test_data_prediction,color= 'green',label= 'Predicted Value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('GLD Price')
plt.legend()
xplt.show()

# %%
# compare linear Regression vs Random Forest Regressor
# Random Forest Regressor algorithm is high prediction from linear Regression
